# %%
pip install fyers-apiv3
# Out:
# Collecting fyers-apiv3
#   Using cached fyers_apiv3-3.1.11-py3-none-any.whl.metadata (25 kB)
# Collecting requests==2.31.0 (from fyers-apiv3)
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting asyncio==3.4.3 (from fyers-apiv3)
#   Using cached asyncio-3.4.3-py3-none-any.whl.metadata (1.7 kB)
# Collecting aiohttp==3.9.3 (from fyers-apiv3)
#   Downloading aiohttp-3.9.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting aws-lambda-powertools==1.25.5 (from fyers-apiv3)
#   Using cached aws_lambda_powertools-1.25.5-py3-none-any.whl.metadata (6.8 kB)
# Collecting websocket-client==1.6.1 (from fyers-apiv3)
#   Using cached websocket_client-1.6.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting setuptools==68.0.0 (from fyers-apiv3)
#   Downloading setuptools-68.0.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp==3.9.3->fyers-apiv3) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp==3.9.3->fyers-apiv3) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp==3.9.3->fyers-apiv3) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp==3.9.3->fyers-apiv3) (6.4.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp==3.9.3->fyers-apiv3) (1.20.0)
# Collecting aws-xray-sdk<3.0.0,>=2.8.0 (from aws-lambda-powertools==1.25.5->fyers-apiv3)
#   Using cached aws_xray_sdk-2.15.0-py2.py3-none-any.whl.metadata (23 kB)
# Collecting boto3<2.0,>=1.18 (from aws-lambda-powertools==1.25.5->fyers-apiv3)
#   Downloading boto3-1.42.64-py3-none-any.whl.metadata (6.7 kB)
# Collecting fastjsonschema<3.0.0,>=2.14.5 (from aws-lambda-powertools==1.25.5->fyers-apiv3)
#   Using cached fastjsonschema-2.21.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting jmespath<0.11.0,>=0.10.0 (from aws-lambda-powertools==1.25.5->fyers-apiv3)
#   Using cached jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests==2.31.0->fyers-apiv3) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests==2.31.0->fyers-apiv3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests==2.31.0->fyers-apiv3) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests==2.31.0->fyers-apiv3) (2024.8.30)
# Requirement already satisfied: wrapt in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aws-xray-sdk<3.0.0,>=2.8.0->aws-lambda-powertools==1.25.5->fyers-apiv3) (1.16.0)
# Collecting botocore>=1.11.3 (from aws-xray-sdk<3.0.0,>=2.8.0->aws-lambda-powertools==1.25.5->fyers-apiv3)
#   Downloading botocore-1.42.64-py3-none-any.whl.metadata (5.9 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3<2.0,>=1.18->aws-lambda-powertools==1.25.5->fyers-apiv3)
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: propcache>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from yarl<2.0,>=1.0->aiohttp==3.9.3->fyers-apiv3) (0.3.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/anshulyadav/Library/Python/3.11/lib/python/site-packages (from botocore>=1.11.3->aws-xray-sdk<3.0.0,>=2.8.0->aws-lambda-powertools==1.25.5->fyers-apiv3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/anshulyadav/Library/Python/3.11/lib/python/site-packages (from python-dateutil<3.0.0,>=2.1->botocore>=1.11.3->aws-xray-sdk<3.0.0,>=2.8.0->aws-lambda-powertools==1.25.5->fyers-apiv3) (1.16.0)
# Downloading fyers_apiv3-3.1.11-py3-none-any.whl (44 kB)
# Downloading aiohttp-3.9.3-cp311-cp311-macosx_11_0_arm64.whl (387 kB)
# Using cached asyncio-3.4.3-py3-none-any.whl (101 kB)
# Using cached aws_lambda_powertools-1.25.5-py3-none-any.whl (171 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Downloading setuptools-68.0.0-py3-none-any.whl (804 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 804.0/804.0 kB 2.3 MB/s eta 0:00:00a 0:00:01
# Using cached websocket_client-1.6.1-py3-none-any.whl (56 kB)
# Using cached aws_xray_sdk-2.15.0-py2.py3-none-any.whl (103 kB)
# Downloading boto3-1.42.64-py3-none-any.whl (140 kB)
# Using cached fastjsonschema-2.21.2-py3-none-any.whl (24 kB)
# Using cached jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Downloading botocore-1.42.64-py3-none-any.whl (14.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 3.0 MB/s eta 0:00:00a 0:00:01
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
# Installing collected packages: fastjsonschema, asyncio, websocket-client, setuptools, requests, jmespath, botocore, aiohttp, s3transfer, aws-xray-sdk, boto3, aws-lambda-powertools, fyers-apiv3
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.8.0
#     Uninstalling websocket-client-1.8.0:
#       Successfully uninstalled websocket-client-1.8.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 65.5.0
#     Uninstalling setuptools-65.5.0:
#       Successfully uninstalled setuptools-65.5.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.10.11
#     Uninstalling aiohttp-3.10.11:
#       Successfully uninstalled aiohttp-3.10.11
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.45.0 requires packaging<25,>=20, but you have packaging 25.0 which is incompatible.
# tensorflow 2.17.0 requires numpy<2.0.0,>=1.23.5; python_version <= "3.11", but you have numpy 2.3.4 which is incompatible.
# instructor 1.10.0 requires requests<3.0.0,>=2.32.3, but you have requests 2.31.0 which is incompatible.
# mem0ai 0.1.116 requires protobuf<6.0.0,>=5.29.0, but you have protobuf 4.25.8 which is incompatible.
# litellm 1.74.9 requires aiohttp>=3.10, but you have aiohttp 3.9.3 which is incompatible.
# embedchain 0.1.128 requires chromadb<0.6.0,>=0.5.10, but you have chromadb 1.1.1 which is incompatible.
# Successfully installed aiohttp-3.9.3 asyncio-3.4.3 aws-lambda-powertools-1.25.5 aws-xray-sdk-2.15.0 boto3-1.42.64 botocore-1.42.64 fastjsonschema-2.21.2 fyers-apiv3-3.1.11 jmespath-0.10.0 requests-2.31.0 s3transfer-0.16.0 setuptools-68.0.0 websocket-client-1.6.1
#
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the required module from the fyers_apiv3 package -- access token
from fyers_apiv3 import fyersModel

# Replace these values with your actual API credentials
client_id = "-100"  # Replace with your client ID
secret_key = ""  # Replace with your secret key
redirect_uri = "https://127.0.0.1/8000"  # Replace with your redirect URI
response_type = "code"
state = "sample_state"

# Create a session model with the provided credentials
session = fyersModel.SessionModel(
    client_id=client_id,
    secret_key=secret_key,
    redirect_uri=redirect_uri,
    response_type=response_type
)

# Generate the auth code using the session model
response = session.generate_authcode()

# Print the auth code received in the response
print(response)

# %%
# Import the required module from the fyers_apiv3 package. -- AUTH TOKEN
from fyers_apiv3 import fyersModel

# Define your Fyers API credentials
client_id = "03QJI54K7U-100"  # Replace with your client ID
secret_key = "1JPME3WOU4"  # Replace with your secret key
redirect_uri = "https://127.0.0.1/8000"  # Replace with your redirect URI
response_type = "code"
grant_type = "authorization_code"

# The authorization code received from Fyers after the user grants access
auth_code = ""

# Create a session object to handle the Fyers API authentication and token generation
session = fyersModel.SessionModel(
    client_id=client_id,
    secret_key=secret_key,
    redirect_uri=redirect_uri,
    response_type=response_type,
    grant_type=grant_type
)

# Set the authorization code in the session object
session.set_token(auth_code)

# Generate the access token using the authorization code
response = session.generate_token()

# Print the response, which should contain the access token and other details
print(response)
